# %% [markdown]
# # Проект SocialSearch

# %% [markdown]
# ## Тематические статьи
# Про графы:
# - [Хорошая статья на хабре про кластеризацию графив](https://habr.com/ru/company/dca/blog/265077/)
# - [алгоритм louvain](https://louvain-igraph.readthedocs.io/en/latest/index.html)
# - [Awesome Community Detection Research Papers](https://github.com/benedekrozemberczki/awesome-community-detection)
#
#
# Про нахождение информации о человеке:
# - https://bsfo.ru/threads/probiv-cheloveka-v-vk.4110/
# - https://www.iphones.ru/iNotes/705983
# - https://cryptoworld.su/5-sposobov-probit-informaciyu-o-cheloveke-v-seti/
# - https://habr.com/en/company/echelon/blog/321754/ Отличная статья на хабре
#
#
# Лайфкаки по поиску информации:
# - https://vk.com/feed?obj=1&q=&section=mentions
# - [Каталог пользователей вк](https://vk.com/catalog.php)
# - https://vk.com/foaf.php?id=245089915 Посмотреть код страницы
# - http://сервисы.гувм.мвд.рф/info-service.htm?sid=2000 Провека действительности паспорта
#
# Конкуренты (похожие проекты):
# - https://bazaman.ru/ Нахождение человека по данным. Работает хреново
# - https://poiski-people.ru/instrukziya.html Плохо работает [То, что нашли обо мне](https://poiski-people.ru/rossiya/moskva/boris-novichkov-moskva-90185.html)
# - https://people.yandex.ru (Поиск людей по различной информации)
# - https://poisk-help.ru/ Работает плохо [Обо мне](https://poisk-help.ru/rossiya/moskva/boris-novichkov-moskva-2959.html)
# - http://spys.one/vk/ Банальное копирование вк. Только информация со страницы пользователя
# - https://vk.barkov.net/userinfo.aspx Требует доступ к странице. Базовая информация
#
# Получение ключа доступа пользователя для vk api
# https://oauth.vk.com/authorize?client_id=7091370&scope=photos,audio,video,docs,notes,pages,status,offers,questions,wall,groups,notifications,stats,ads,offline,docs,pages,stats,notifications,wall,friends&response_type=token

# %% [markdown]
# # Задачи проекта:
# 1. Найти человека по минимальномо количеству известных о нем данных
# 2. Получить всю возможную инфомацию о человеке из открытых источников (социальные сети, гос. порталы, гугл, некоторые сайты)
# 3. Проанализировать (аналитичестки, с помощью ML)
# 4. Предоставить все в красивом человеко-читаемом виде конечному потребителю (пользователю данного ресурса)

# %% [markdown]
# ## Информация о человеке
# ### Базовые аспекты
# *Поля страницы вк: first_name, last_name, photo_200, sex, bdate, city, country, relatives, home_town, maiden_name, relation*
# - Имя
# - Вевичья фамилия
# - Фото
# - Пол
# - Возраст
# - Страна
# - Родной город
# - Родственники
#
#
# ### Основная деятельность (в настоящем / прошлом)
# *Поля страницы вк: career, education, occupation, schools, universities, military*
# - Школа (класс, год)
# - Вуз (факультет, курс, год)
# - Работа (направленность, год)
# - Бизнес (направления, сайт и пр)
#
# ### Сетевая жизнь / Контакты
# *Поля страницы вк: nickname, online, site, exports, contacts, verified, last_seen, connections, followers_count*
# - Сайт
# - Все социальные сети
# - Подписчики
# - Verify
# - Приватный аккаунт
#
# ### Интересы / Занятия
# *Поля страницы вк: books, activities, movies, music, tv, trending, games, interests, quotes*
# - Увлечения
# - Хобби
# - Музыка Фильмы Игры Книги
#
# ### Характеристика / Анализ
# *Поля страницы вк: status, counters, personal, about*
#
# *Информация на основе всех имеющихся данных*
# - Экстраверт / Интроверт (в процентах)
# - Популярность в сети (Подписчики, друзья и тд)
# - Сетевая доступность (в процентах). Количество личной информации в сети
# - Общественный статус (один из нескольких вариантов)
# - Процент одиночных друзей (не состоящих в сообществах испытуемого)
# - Придумать еще что-нибудь!

# %% [markdown]
# ## Социальные сообщества человека
# **Любые группы людей, к которым относится испытуемый:**
# - Социальные объединения среди друзей
# - Сообщества на основе общих групп
# - Виртуальное объединение на основе общего интереса (несвязные друзья программисты)
#
# ### Операции над сообществами
# - Поиск полного коллектива из небольшой его части
#
# ### Параметры каждого объединения
# - Список всех объединяющих коллектив факторы (место учебы, интересы, возраст, пол и пр)
# - Связность сообщества (исходя из графа)
# - Размер сообщества (количество участников)
# - Тут можно много чего еще придумать!

# %%
import numpy as np
import pandas as pd
from skimage import io
import networkx as nx
import random
import matplotlib.pyplot as plt
import vk
from community import Community
import warnings
warnings.filterwarnings("ignore")

import collections
from collections import Counter
import datetime
from time import time
import functools
from vkuser import VKUser
from collections import Counter
import networkx as nx
import math
from main import *

# %%
# %matplotlib qt
# %matplotlib inline
user = VKUser('https://vk.com/id200109760')
user.groups.color_graph(save_path='1.png')

# %%
id = 86
itmes = user.groups.pools() + user.friends.pools()
pools_dict = dict([(item.id, item) for item in itmes])
pools_dict[id].print_groups()
# Out:
# * VK API Request: %s friends
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3b6c5ede251e> in <module>
#       2 itmes = user.groups.pools() + user.friends.pools()
#       3 pools_dict = dict([(item.id, item) for item in itmes])
# ----> 4 pools_dict[id].print_groups()
#
# AttributeError: 'GroupsPool' object has no attribute 'print_groups'

# %%
i = 1
user.groups.pools()[i].print()
# user.groups.pools()[i].params['groups_pages_activity'].most_common()
# Out:
# анекдотов.net 22222333 https://vk.com/anekdot
# Политика Путина 23977193 https://vk.com/kremlin_rf
# Гифки 26005665 https://vk.com/club26005665
# Эта весёлая Россия 36959483 https://vk.com/vk.policyhumor
# География в опросах 73484869 https://vk.com/z_nature
# Взрослый Юмор 99800441 https://vk.com/humor_tev
# Вездеходы 111205860 https://vk.com/vezdexood
# Подслушано Метро Москвы 144260965 https://vk.com/pmmgo
# Добрые мемы : ) 147286578 https://vk.com/dobriememes
# ШВТ 152219848 https://vk.com/shvt
# Рассказано 153286036 https://vk.com/narrated
# Закрытая афиша Москвы 154852658 https://vk.com/mosctop
# За кадром 163182607 https://vk.com/vip_pub777

# %%
from sklearn.preprocessing import normalize
x = np.random.rand(5)*10
norm1 = x / np.linalg.norm(x)
norm2 = normalize(x[:,np.newaxis], axis=0).ravel()
norm1
# Out:
# array([0.37320257, 0.70729868, 0.14509851, 0.55634512, 0.17284372])

# %%
my_groups = user.groups_pool.groups_data
my_groups = sorted(my_groups, key=lambda x: x['members_count'])
groups = np.array([(gr['members_count'], gr['name']) for gr in my_groups])
print(groups)
# np.median(groups[:,0])
median = np.median(groups[:,0].astype(int)).astype(int)
dict(groups)[str(median)]
# Out:
# [['3' 'mdd test']
#  ['119' 'Telarld']
#  ['174' 'Официальная страница журнала "Ростки Ковчега"']
#  ['186' 'Просмотры и трансляции ФИВТ']
#  ['296' 'Алексей Кириллов. Портретный и семейный фотограф']
#  ['351' 'ФПМИ.Индустрия 1 курс']
#  ['440' 'Академия искусственного интеллекта']
#  ['448' 'фтл каждый день']
#  ['527' 'Театр-студия "МАЛАХИТ" Олега Малахова']
#  ['598' 'Фонд целевого капитала МФТИ']
#  ['602' 'День Первокурсника МФТИ 2019']
#  ['1056' 'Учебные материалы ФИВТ (Оф. клуб любителей Го)']
#  ['1217' 'Семейная школа поселения родовых поместий Ковчег']
#  ['1246' 'CulturALL Reboot']
#  ['1295' 'Питомник-БотСад-Поместье | сеянцы, саженцы |']
#  ['1413' 'Абитуриенты ФПМИ МФТИ']
#  ['1617' 'Студсовет ФИВТ']
#  ['1870' 'Soft skills в МФТИ']
#  ['1916' 'MIPT(Moscow Institute of Physics and Technology)']
#  ['2003' 'Физтех Тур']
#  ['2013' 'клуб любителей дискретной постиронии']
#  ['2039' 'ФПМИ МФТИ']
#  ['2584' 'СНПО «Бакалавры Физтеха»']
# ...

# %%
# %matplotlib inline
user = VKUser('https://vk.com/didiv2000')
#user.friends_com.color_communities(user.friends_com.split())
plt.hist(user.friends_com.params['age_list'], bins=25)
plt.show()
user.friends_com.params['age_median']
# Out:
# 40.12472437003373

# %%
activities_types = Counter()

# %%
for i in range(1000):
    print("LOOP", i)
    try:
        user = VKUser.get_random_user()
#         user.print()
#         user.friends_com.show_graph()
#         comms = user.get_communities()
        com = user.friends_com
#         for com in comms:
        items = list(com.community_groups.from_most_common(25).params['groups_pages_activity'])
        activities_types += Counter(items)
        print(len(list(activities_types)))
    except:
        user.print()
# Out:
# LOOP 0
# * VK API Request: %s users
# * VK API Request: %s friends
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# 295
# LOOP 1
# * VK API Request: %s users
# * VK API Request: %s friends
# * VK API Request: %s execute
# * VK API Request: %s execute
# 295
# LOOP 2
# * VK API Request: %s users
# * VK API Request: %s friends
# * VK API Request: %s execute
# Светлана Лепехова 206988099 https://vk.com/id206988099
# LOOP 3
# * VK API Request: %s users
# * VK API Request: %s friends
# * VK API Request: %s execute
# VK API error 6. Too many requests per second. Wait 1 seconds
# VK API error 6. Too many requests per second. Wait 1 seconds
# * VK API Request: %s execute
# * VK API Request: %s execute
# 295
# LOOP 4
# ...

# %%
print(len(activities_types))
activities_types.most_common()
# Out:
# 370
# [('Юмор', 860),
#  ('Кино', 608),
#  ('Городское сообщество', 563),
#  ('Интернет-СМИ', 448),
#  ('Обмен музыкой', 416),
#  ('Творчество', 368),
#  ('Публичная страница', 348),
#  ('Кулинария, рецепты', 342),
#  ('Литература', 304),
#  ('Отношения полов', 276),
#  ('Уход за собой', 255),
#  ('Образование', 255),
#  ('Наука', 251),
#  ('ВКонтакте', 244),
#  ('Объявления', 244),
#  ('Общество', 235),
#  ('Молодёжное движение', 224),
#  ('Шоу, передача', 211),
#  ('Бизнес', 209),
#  ('Знакомства', 200),
#  ('Здоровый образ жизни', 193),
#  ('Философия', 190),
#  ('Стиль, одежда, обувь', 186),
#  ('Фотография', 166),
#  ('Туризм, путешествия', 162),
#  ('Автомобили', 148),
#  ('Дизайн интерьера', 147),
#  ('Музыка', 143),
#  ('Игры', 134),
#  ('Телеканал', 129),
#  ('Родители и дети', 126),
#  ('Фитнес', 125),
#  ('Культура', 102),
#  ('Друзья', 99),
#  ('СМИ', 95),
#  ('Строительство, ремонт', 89),
#  ('Поиск работы', 88),
#  ('Вымышленный персонаж', 86),
#  ('Сайты', 85),
# ...

# %%
print(len(activities_types))
activities_types.most_common()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e937f5c8abe> in <module>
# ----> 1 print(len(activities_types))
#       2 activities_types.most_common()
#
# NameError: name 'activities_types' is not defined

# %%
url = 'boris2000n'
user = VKUser(url)
comms = user.get_communities()
# user.friends_com.color_communities(comms)
# sum([com.size for com in comms])
# user.friends_com.size
# Out:
# * VK API Request: %s execute
# * VK API Request: %s friends
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute
# * VK API Request: %s execute

# %%
activities_types.most_common()
# Out:
# [('Юмор', 8),
#  ('Образование', 7),
#  ('Интернет-СМИ', 5),
#  ('Наука', 4),
#  ('Творчество', 4),
#  ('Политика', 4),
#  ('Программирование', 3),
#  ('Молодёжное движение', 3),
#  ('Кино', 3),
#  ('Шоу, передача', 3),
#  ('Театр', 2),
#  ('Университет', 2),
#  ('Институт', 2),
#  ('Дом культуры', 2),
#  ('Видеоигры', 2),
#  ('Фотография', 2),
#  ('Салон красоты', 2),
#  ('Вымышленный персонаж', 2),
#  ('Знакомства', 2),
#  ('Общественная организация', 2),
#  ('Литература', 2),
#  ('Другие хобби', 2),
#  ('Мобильные технологии', 2),
#  ('ВКонтакте', 2),
#  ('Общество', 2),
#  ('Родители и дети', 1),
#  ('Домашние и дикие животные', 1),
#  ('Товар', 1),
#  ('Лицей', 1),
#  ('Игры', 1),
#  ('Онлайн-игра', 1),
#  ('Сериал', 1),
#  ('Дискуссионный клуб', 1),
#  ('Музыка', 1),
#  ('Культура', 1),
#  ('Творческое объединение', 1),
#  ('Музыкальный лейбл', 1),
#  ('Одежда, обувь', 1),
#  ('Музей, галерея, выставка', 1),
#  ('Уход за собой', 1),
#  ('Телеканал', 1),
# ...

# %%
def getLikes(user_id, cnt, api):
    import time
    # подписки пользователя
    subscriptions_list = api.users.getSubscriptions(user_id=user_id,extended=0)['groups']['items']
    # формируем список id, который нужно передать в следующий метод
    groups_list = ['-' + str(x) for x in subscriptions_list]
    posts = {}
    # формируем ленту новостей
    newsfeed = api.newsfeed.get(
        filters='post',
        source_ids=', '.join(groups_list),
        count=100, timeout=10)
    # добавляем посты в словарь в формате id_поста: id_группы
    posts.update({x['post_id']: x['source_id'] for x in newsfeed['items']})
    # нужно для получения следующей партии
    # если требуется более одного запроса — делаем остаток в цикле
    if cnt != 1:
        for c in range(cnt - 1):
            next_from = newsfeed['start_from']
            kwargs = {
                'from': next_from,
                'filters': 'post',
                'source_ids': ', '.join(groups_list),
                'count': 100,
                'timeout': 10
            }
            newsfeed = api.newsfeed.get(**kwargs)
 
            posts.update({x['post_id']: x['source_id'] for x in newsfeed['items']})
#             time.sleep(1)
    liked_posts = []
 
    print('Лайкнутые посты:')
    for post in posts.items():
        try:
            itemID = post[0]
            ownerID = post[1]
            timeOut = 5
            isLiked = api.likes.isLiked(
                user_id=user_id,
                item_id=itemID,
                type='post',
                owner_id=ownerID,
                timeout=timeOut)['liked']
        except Exception:
#             print('ERROR! ' + 'vk.com/wall{0}_{1}'.format(post[1], post[0]))
            isLiked = 0
#         print(isLiked)
        if isLiked:
#             liked_posts.append('vk.com/wall{0}_{1}'.format(post[1], post[0]))
            print('https://vk.com/wall{}_{}'.format(post[1], post[0]))
            time.sleep(0.25)
    return liked_posts
getLikes(user.vkid, 0, bapi.api_user)
# Out:
# * VK API Request: %s users
# * VK API Request: %s newsfeed
# Лайкнутые посты:
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# VK API error 6. Too many requests per second. Wait 1 seconds
# VK API error 6. Too many requests per second. Wait 1 seconds
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# VK API error 6. Too many requests per second. Wait 1 seconds
# VK API error 6. Too many requests per second. Wait 1 seconds
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# * VK API Request: %s likes
# ...

# %%
user.print()
# Out:
# Борис Новичков 245089915 https://vk.com/id245089915

# %%
com0.community_groups.from_most_common(30).print_groups()
# Out:
# Ферма изобилия "Родники"
# Семинары в экопоселении Ковчег
# Семена из экопоселения Ковчег
# Типичный Малоярославец
# Детский поселок "Орион"
# ИЗ ГОРОДА В ДЕРЕВНЮ
# Школа эффективного обучения
# свалке НЕТ
# Историко-деловая игра “Эпоха Наполеоновских войн
# Семена старых сортов растений
# Детская газета "Росточки Ковчега"
# Лучшие стихи великих поэтов | Литература
# Вселенная в рукаве
# Семейная школа поселения родовых поместий Ковчег
# Официальная страница журнала "Ростки Ковчега"
# Без кота и жизнь не та ツ
# Студия авторского текстиля Порт Лисс
# РАССВЕТ ИСКОНИ
# Алексей Кириллов. Портретный и семейный фотограф
# Движение Жизни
# Интересные идеи handmade, рукоделие и советы
# Быть добру
# Экопоселение Родовых Поместий КОВЧЕГ
# КЛУБ ОСОЗНАННЫХ И ЛЮБЯЩИХ РОДИТЕЛЕЙ-дети и семья
# ПРИКОЛЫ | Смеяка
# Театр-студия "МАЛАХИТ" Олега Малахова
# Питомник-БотСад-Поместье | сеянцы, саженцы |
# Миры Катрин Дракос
# 7-ой ФЕСТИВАЛЬ ЭКОТЕХНОЛОГИЙ
# Семена | Народный Фонд Семян

# %%
#petr 191215854
#boris 245089915
my_id = 245089915

# %% [markdown]
# ## Выявление сообществ на графе друзей испытуемого

# %% [markdown]
# ### Алгоритм Label propagation

# %%
node_group = dict([(node, i) for i, node in enumerate(G.nodes)])
new_node_group = {}
nodes = G.nodes
for ii in range(min(len(node_group) * 10, 1000)):
#     print(ii)
    for node in random.sample(nodes, len(nodes)):
        ne_groups = {}
        neighbors = G.neighbors(node)
        for ne in neighbors:
            ne_group = node_group[ne]
            ne_groups[ne_group] = ne_groups.get(ne_group, 0) + 1
        new_group = sorted(ne_groups.items(), key=lambda x: x[1])[-1][0]
        new_node_group[node] = new_group
#     break
    if new_node_group == node_group:
        print(ii)
        break
    node_group = new_node_group.copy()
for node in list(node_group.keys()).copy():
    if len(list(G.neighbors(node))) == 1:
#         print(node)
        node_group[node] = 1e9
# Out:
# 8

# %%
b = {}
for key, value in node_group.items():
    b[value] = b.get(value, []) + [key]
b = list(b.values())
a = b
print(a)
# Out:
# [[378420873, 190016644, 177014487, 437530634, 378235354, 284097634, 259874028, 349502792, 272023406, 210666906, 415803087, 316639638, 178862426, 141158225, 402705610, 193795087, 415808612, 181857, 125646982, 235933101, 344871324, 211915613, 13759701, 370504157, 271552501, 2999879, 435265609, 231293500, 326754942, 195097896, 2269407, 200109760, 57026122, 68559338, 107893278, 288686280, 71561540, 274928641, 155987360, 140878439, 341467094, 7024732, 265405579, 396970062, 255988223, 310687612, 230749912, 493754172, 123543974, 245089915, 453566375, 200064897, 91888646, 314043174, 344735749, 269339915, 1225528, 20352294, 245520002, 199148993, 75011672, 372043906], [99468653, 183097641, 102038177, 219639443, 24792293, 445138646, 255725430, 143645548, 368083402, 217970740, 191215854, 222901639, 370285501, 362289, 119984871, 355269411, 248819266, 361020825, 127666046, 1384602, 166141735, 286796214, 215297094, 17778872, 290972119, 272539771, 89534190, 146074673, 277313001, 271594863, 171798925
# ...

# %% [markdown]
# ## Отрисовка разделенного на сообщества графа друзей

# %%
# %%time
node_colors = pd.Series(dict(sum([list(zip(arr, [get_color(i + 1)] * len(arr))) for i, arr in enumerate(a)], [])))[np.array(G.nodes)].fillna(get_color(0)).values
# node_colors = 'r'
plt.figure(figsize=(8,8))
options = {
    'node_color': node_colors,
    'node_size': 50,
    'width': 1,
    'with_labels': False,
    'font_size': 8
}

nx.draw(G, **options)
# Out:
# CPU times: user 126 ms, sys: 71.9 ms, total: 198 ms
# Wall time: 81.2 ms

# %% [markdown]
# ## Нахождение полного сообщества по нескольким участникам

# %%
base_community = np.array(a[1])

# %%
def print_func_plot(func, params, x=None):
    results = []
    for args in params:
        results.append(func(**args))
    if x is None:
        x = range(len(results))
    plt.plot(x, results)
    plt.show()

# %%
x = np.linspace(0.1, 0.98, num=20)
print_func_plot(
    get_community_size, 
    [
        {
            'weight_reduction_ratio': i,
            'break_point': 10,
        }
        for i in x
    ],
    x=x
)

# %% [markdown]
# ## Нахождение общего знаменателя среди сообщества (школа, вуз, место жительста, группы вк и т.д)

# %%
from community import Community
Community.generate_random(20).print_users(5)
# Out:
# Serj Karaush https://vk.com/id413176842
# Эльвира Марсова https://vk.com/id404693545
# Евгений Добрый https://vk.com/id349755405
# Борис Юльметьев https://vk.com/id175167265
# Ира Туманова https://vk.com/id228994866

# %%
# comm1 = Community.from_nodes_part(base_community)
# comm1.print_users(2)
# Out:
# Никита Брюзгин https://vk.com/id166141735
# Елизавета Шерстнёва https://vk.com/id170099909

# %%
Community.from_nodes_part([my_id, 269339915, 493754172, 211915613], 
                          weight_reduction_ratio=0.5, break_point=3).get_special_params()
# Out:
# * Get user data 245520002
# * Get user data 372043906
# * Get user data 190016644
# * Get user data 344735749
# * Get user data 125646982
# * Get user data 295948807
# * Get user data 437530634
# * Get user data 269339915
# * Get user data 265405579
# * Get user data 193795087
# * Get user data 344871324
# * Get user data 155987360
# * Get user data 504638756
# * Get user data 20352294
# * Get user data 123543974
# * Get user data 195097896
# * Get user data 314043174
# * Get user data 453566375
# * Get user data 235933101
# * Get user data 493754172
# * Get user data 231293500
# * Get user data 200109760
# * Get user data 199148993
# * Get user data 402705610
# * Get user data 157185614
# * Get user data 415803087
# * Get user data 396970062
# * Get user data 13759701
# * Get user data 341467094
# * Get user data 230749912
# * Get user data 211915613
# * Get user data 415808612
# * Get user data 140878439
# * Get user data 272023406
# * Get user data 271552501
# ...

# %%
from tqdm import tqdm_notebook as tqdm
for i in tqdm(range(2)):
    size = np.random.randint(20, 250)
    params = Community.generate_random(size).get_special_params()
#     print(params)
    CommunityData.create(data=params)

# %%
comm_data = [i.data for i in CommunityData.select().execute()]
def param_list(key):
    return [x[key] for x in comm_data]
params = ['community_size', 'sex_mean', 'age_median', 'city_first_fr', 
'country_first_fr', 'online_mean', 'online_mobile_mean', 
'verified_mean', 'last_seen_mean', 'last_seen_amax', 
'last_seen_median', 'site_fr', 'followers_count_mean', 
'followers_count_median', 'followers_count_amax', 'home_town_first_fr', 
'occupation_type_first_fr', 'occupation_name_first_fr', 'personal_langs_first_fr', 
'personal_political_first_fr', 'personal_religion_first_fr', 'personal_people_main_first_fr', 
'personal_smoking_first_fr', 'personal_alcohol_first_fr', 'personal_life_main_first_fr', 
'relatives_childs_fr', 'relation_first_fr', 'schools_first_fr', 
'schools_type_str_first_fr', 'status_fr']

# %%
# Community.generate_random(1).special_params
for p in params:
    print(p)
    l = param_list(p)
    plt.hist(l, 20)
    plt.show()
# Out:
# community_size
# sex_mean
# age_median
# city_first_fr
# country_first_fr
# online_mean
# online_mobile_mean
# verified_mean
# last_seen_mean
# last_seen_amax
# last_seen_median
# site_fr
# followers_count_mean
# followers_count_median
# followers_count_amax
# home_town_first_fr
# occupation_type_first_fr
# occupation_name_first_fr
# personal_langs_first_fr
# personal_political_first_fr
# personal_religion_first_fr
# personal_people_main_first_fr
# personal_smoking_first_fr
# personal_alcohol_first_fr
# personal_life_main_first_fr
# relatives_childs_fr
# relation_first_fr
# schools_first_fr
# schools_type_str_first_fr
# status_fr

# %%
key_importance = []
target_community = comm1.get_params()

for key in params:
    target_element = target_community[key]
#     print(target_element)
    hist_list = param_list(key)
    bins = 10
    hist_values, hist_x = np.histogram(hist_list, bins)
#     plt.hist(hist_list, bins)
#     plt.show()
#     print(hist_x)
    if target_element < hist_x[0]:
        hist_value = 0
    elif target_element > hist_x[-1]:
        hist_value = 0
    else:
        hist_column = np.where(hist_x <= target_element)[0][-1]
        hist_value = hist_values[hist_column]

    hist_max = np.max(hist_values)
    element_importance = hist_value / hist_max
    key_importance.append((element_importance, key))
#     print(hist_max)
#     print(element_fr)
[print(i) for i in sorted(key_importance)]
None
# Out:
# * Get user data 229170215
# * Get user data 2384937
# * Get user data 327191868
# * Get user data 1727556
# * Get user data 150879566
# * Get user data 349087825
# * Get user data 305752720
# * Get user data 280349348
# * Get user data 332072868
# * Get user data 179897523
# * Get user data 203419100
# (0.0, 'age_median')
# (0.0, 'city_first_fr')
# (0.0, 'country_first_fr')
# (0.0, 'followers_count_median')
# (0.0, 'home_town_first_fr')
# (0.0, 'last_seen_amax')
# (0.0, 'last_seen_mean')
# (0.0, 'last_seen_median')
# (0.0, 'occupation_name_first_fr')
# (0.0, 'occupation_type_first_fr')
# (0.0, 'online_mean')
# (0.0, 'schools_first_fr')
# (0.0, 'schools_type_str_first_fr')
# (0.0, 'status_fr')
# (0.012, 'online_mobile_mean')
# (0.07692307692307693, 'site_fr')
# (0.09818181818181818, 'followers_count_mean')
# (0.13664596273291926, 'personal_smoking_first_fr')
# (0.20382165605095542, 'personal_alcohol_first_fr')
# (0.21674876847290642, 'personal_people_main_first_fr')
# ...

# %%
def once_property(func):
    @property
    def wrapper(class_obj, *args, **kwargs):
        func_name = func.__name__
        class_value_name = f'{func_name}_'
        if hasattr(class_obj, class_value_name):
            return getattr(class_obj, class_value_name)
        method_result = func(class_obj, *args, **kwargs)
        setattr(class_obj, class_value_name, method_result)
        return method_result
    return wrapper

# %%
class A:
    def __getattr__(self, name):
        print('__getattr__', name)
        
    def __call__(self, name, **args):
        print('__call__', name, args)

# %%
items_list = [('Юмор', 860),
 ('Кино', 608),
 ('Городское сообщество', 563),
 ('Интернет-СМИ', 448),
 ('Обмен музыкой', 416),
 ('Творчество', 368),
 ('Публичная страница', 348),
 ('Кулинария, рецепты', 342),
 ('Литература', 304),
 ('Отношения полов', 276),
 ('Уход за собой', 255),
 ('Образование', 255),
 ('Наука', 251),
 ('ВКонтакте', 244),
 ('Объявления', 244),
 ('Общество', 235),
 ('Молодёжное движение', 224),
 ('Шоу, передача', 211),
 ('Бизнес', 209),
 ('Знакомства', 200),
 ('Здоровый образ жизни', 193),
 ('Философия', 190),
 ('Стиль, одежда, обувь', 186),
 ('Фотография', 166),
 ('Туризм, путешествия', 162),
 ('Автомобили', 148),
 ('Дизайн интерьера', 147),
 ('Музыка', 143),
 ('Игры', 134),
 ('Телеканал', 129),
 ('Родители и дети', 126),
 ('Фитнес', 125),
 ('Культура', 102),
 ('Друзья', 99),
 ('СМИ', 95),
 ('Строительство, ремонт', 89),
 ('Поиск работы', 88),
 ('Вымышленный персонаж', 86),
 ('Сайты', 85),
 ('Искусство и развлечения', 78),
 ('Rap, Hip-Hop', 74),
 ('Футбол', 74),
 ('Дискуссионный клуб', 73),
 ('Автовладельцы', 69),
 ('Домашние и дикие животные', 69),
 ('Дизайн и графика', 67),
 ('Астрология, эзотерика', 66),
 ('Сайт', 65),
 ('Общественная организация', 62),
 ('Товары, магазины', 62),
 ('Спортивная организация', 61),
 ('История', 60),
 ('Культурный центр', 59),
 ('Одежда, обувь', 58),
 ('Другие хобби', 57),
 ('Развлечения', 55),
 ('Музыкант', 52),
 ('Анимация', 51),
 ('Спорт', 49),
 ('Кинотеатр', 47),
 ('Фан-клуб', 40),
 ('Религия', 39),
 ('Видеоигры', 39),
 ('Стиль, мода', 38),
 ('Эротика', 38),
 ('Страна', 38),
 ('Доставка еды', 37),
 ('Музыкальная группа', 36),
 ('Общественный деятель', 35),
 ('Поэт / Поэтесса', 33),
 ('Блог', 33),
 ('Медицина', 33),
 ('Языки', 32),
 ('Товары для дома', 30),
 ('Торговый центр', 30),
 ('Фото- и видеосъёмка', 29),
 ('Блогер', 29),
 ('Недвижимость', 28),
 ('Интернет-магазин', 26),
 ('Благотворительность', 25),
 ('Танцевальная музыка', 25),
 ('Футбольная команда', 25),
 ('Творческое объединение', 25),
 ('Соседи', 24),
 ('Кафе, ресторан', 23),
 ('Видеоигра', 23),
 ('Сериал', 23),
 ('Радиостанция', 23),
 ('Ночной клуб', 22),
 ('Государственная организация', 22),
 ('Приложение', 22),
 ('Реклама', 22),
 ('Книга', 22),
 ('Садоводство', 21),
 ('Активный отдых', 21),
 ('Певец / Певица', 20),
 ('Политика', 20),
 ('Торгово-развлекательный центр', 20),
 ('Салон красоты', 20),
 ('Мобильные технологии', 19),
 ('Печатное издание', 19),
 ('Электронная музыка', 19),
 ('Мебель', 18),
 ('Фильм', 18),
 ('Университет', 18),
 ('Клуб', 18),
 ('Боевые искусства', 18),
 ('Место отдыха', 17),
 ('Банк, финансовое учреждение', 17),
 ('Группа коллег', 17),
 ('Комик', 16),
 ('Товар', 16),
 ('Туристическое агентство', 16),
 ('Журналист', 16),
 ('Автотовары', 16),
 ('Образовательное учреждение', 15),
 ('Обучающие курсы', 14),
 ('Дом культуры', 14),
 ('Писатель / Писательница', 14),
 ('Программное обеспечение', 14),
 ('Потребительские товары', 13),
 ('Общественное движение', 13),
 ('Финансы', 13),
 ('Издательский дом', 13),
 ('Рок', 13),
 ('Парфюмерия, косметика', 12),
 ('Спортсмен / Спортсменка', 12),
 ('Альбом', 12),
 ('Магазин', 12),
 ('Электроника', 12),
 ('DJ', 12),
 ('Театр', 11),
 ('Благотворительная организация', 11),
 ('Организация', 11),
 ('Мототехника', 11),
 ('Фотограф', 11),
 ('Духовное лицо', 11),
 ('Военное дело', 10),
 ('Парк отдыха', 10),
 ('Персонаж', 10),
 ('Продукты питания, напитки', 10),
 ('Кулинария', 10),
 ('Техника, электроника', 10),
 ('Товары для детей', 10),
 ('Покупки', 9)]

# %%
print(list([i[0] for i in items_list]))
# Out:
# ['Юмор', 'Кино', 'Городское сообщество', 'Интернет-СМИ', 'Обмен музыкой', 'Творчество', 'Публичная страница', 'Кулинария, рецепты', 'Литература', 'Отношения полов', 'Уход за собой', 'Образование', 'Наука', 'ВКонтакте', 'Объявления', 'Общество', 'Молодёжное движение', 'Шоу, передача', 'Бизнес', 'Знакомства', 'Здоровый образ жизни', 'Философия', 'Стиль, одежда, обувь', 'Фотография', 'Туризм, путешествия', 'Автомобили', 'Дизайн интерьера', 'Музыка', 'Игры', 'Телеканал', 'Родители и дети', 'Фитнес', 'Культура', 'Друзья', 'СМИ', 'Строительство, ремонт', 'Поиск работы', 'Вымышленный персонаж', 'Сайты', 'Искусство и развлечения', 'Rap, Hip-Hop', 'Футбол', 'Дискуссионный клуб', 'Автовладельцы', 'Домашние и дикие животные', 'Дизайн и графика', 'Астрология, эзотерика', 'Сайт', 'Общественная организация', 'Товары, магазины', 'Спортивная организация', 'История', 'Культурный центр', 'Одежда, обувь', 'Другие хобби', 'Развлечения', 'Музыкант', 'Анимация', 'Спорт', 'Кинотеатр', 'Фан-клуб', 'Религия'
# ...

# %% [markdown]
# [('Юмор', 860),
#  ('Кино', 608),
#  ('Городское сообщество', 563),
#  ('Интернет-СМИ', 448),
#  ('Обмен музыкой', 416),
#  ('Творчество', 368),
#  ('Публичная страница', 348),
#  ('Кулинария, рецепты', 342),
#  ('Литература', 304),
#  ('Отношения полов', 276),
#  ('Уход за собой', 255),
#  ('Образование', 255),
#  ('Наука', 251),
#  ('ВКонтакте', 244),
#  ('Объявления', 244),
#  ('Общество', 235),
#  ('Молодёжное движение', 224),
#  ('Шоу, передача', 211),
#  ('Бизнес', 209),
#  ('Знакомства', 200),
#  ('Здоровый образ жизни', 193),
#  ('Философия', 190),
#  ('Стиль, одежда, обувь', 186),
#  ('Фотография', 166),
#  ('Туризм, путешествия', 162),
#  ('Автомобили', 148),
#  ('Дизайн интерьера', 147),
#  ('Музыка', 143),
#  ('Игры', 134),
#  ('Телеканал', 129),
#  ('Родители и дети', 126),
#  ('Фитнес', 125),
#  ('Культура', 102),
#  ('Друзья', 99),
#  ('СМИ', 95),
#  ('Строительство, ремонт', 89),
#  ('Поиск работы', 88),
#  ('Вымышленный персонаж', 86),
#  ('Сайты', 85),
#  ('Искусство и развлечения', 78),
#  ('Rap, Hip-Hop', 74),
#  ('Футбол', 74),
#  ('Дискуссионный клуб', 73),
#  ('Автовладельцы', 69),
#  ('Домашние и дикие животные', 69),
#  ('Дизайн и графика', 67),
#  ('Астрология, эзотерика', 66),
#  ('Сайт', 65),
#  ('Общественная организация', 62),
#  ('Товары, магазины', 62),
#  ('Спортивная организация', 61),
#  ('История', 60),
#  ('Культурный центр', 59),
#  ('Одежда, обувь', 58),
#  ('Другие хобби', 57),
#  ('Развлечения', 55),
#  ('Музыкант', 52),
#  ('Анимация', 51),
#  ('Спорт', 49),
#  ('Кинотеатр', 47),
#  ('Фан-клуб', 40),
#  ('Религия', 39),
#  ('Видеоигры', 39),
#  ('Стиль, мода', 38),
#  ('Эротика', 38),
#  ('Страна', 38),
#  ('Доставка еды', 37),
#  ('Музыкальная группа', 36),
#  ('Общественный деятель', 35),
#  ('Поэт / Поэтесса', 33),
#  ('Блог', 33),
#  ('Медицина', 33),
#  ('Языки', 32),
#  ('Товары для дома', 30),
#  ('Торговый центр', 30),
#  ('Фото- и видеосъёмка', 29),
#  ('Блогер', 29),
#  ('Недвижимость', 28),
#  ('Интернет-магазин', 26),
#  ('Благотворительность', 25),
#  ('Танцевальная музыка', 25),
#  ('Футбольная команда', 25),
#  ('Творческое объединение', 25),
#  ('Соседи', 24),
#  ('Кафе, ресторан', 23),
#  ('Видеоигра', 23),
#  ('Сериал', 23),
#  ('Радиостанция', 23),
#  ('Ночной клуб', 22),
#  ('Государственная организация', 22),
#  ('Приложение', 22),
#  ('Реклама', 22),
#  ('Книга', 22),
#  ('Садоводство', 21),
#  ('Активный отдых', 21),
#  ('Певец / Певица', 20),
#  ('Политика', 20),
#  ('Торгово-развлекательный центр', 20),
#  ('Салон красоты', 20),
#  ('Мобильные технологии', 19),
#  ('Печатное издание', 19),
#  ('Электронная музыка', 19),
#  ('Мебель', 18),
#  ('Фильм', 18),
#  ('Университет', 18),
#  ('Клуб', 18),
#  ('Боевые искусства', 18),
#  ('Место отдыха', 17),
#  ('Банк, финансовое учреждение', 17),
#  ('Группа коллег', 17),
#  ('Комик', 16),
#  ('Товар', 16),
#  ('Туристическое агентство', 16),
#  ('Журналист', 16),
#  ('Автотовары', 16),
#  ('Образовательное учреждение', 15),
#  ('Обучающие курсы', 14),
#  ('Дом культуры', 14),
#  ('Писатель / Писательница', 14),
#  ('Программное обеспечение', 14),
#  ('Потребительские товары', 13),
#  ('Общественное движение', 13),
#  ('Финансы', 13),
#  ('Издательский дом', 13),
#  ('Рок', 13),
#  ('Парфюмерия, косметика', 12),
#  ('Спортсмен / Спортсменка', 12),
#  ('Альбом', 12),
#  ('Магазин', 12),
#  ('Электроника', 12),
#  ('DJ', 12),
#  ('Театр', 11),
#  ('Благотворительная организация', 11),
#  ('Организация', 11),
#  ('Мототехника', 11),
#  ('Фотограф', 11),
#  ('Духовное лицо', 11),
#  ('Военное дело', 10),
#  ('Парк отдыха', 10),
#  ('Персонаж', 10),
#  ('Продукты питания, напитки', 10),
#  ('Кулинария', 10),
#  ('Техника, электроника', 10),
#  ('Товары для детей', 10),
#  ('Покупки', 9),
#  ('Данный материал заблокирован на территории Российской Федерации на основании требования Генеральной прокуратуры Российской Федерации от 02.03.2014 № 27-27-2014',
#   9),
#  ('Дополнительное образование', 9),
#  ('Спортивная команда', 9),
#  ('Строительные и ремонтные работы', 9),
#  ('Ювелирные изделия', 9),
#  ('Культура и искусство', 9),
#  ('Спортивный клуб', 9),
#  ('Художник / Художница', 9),
#  ('Производство, промышленность', 8),
#  ('R&B', 8),
#  ('Рыбалка', 8),
#  ('Модель', 8),
#  ('Экстремальный спорт', 8),
#  ('Шоу', 8),
#  ('Программирование', 8),
#  ('Автосервис', 8),
#  ('Веб-студия', 8),
#  ('Услуга', 8),
#  ('Книжный магазин', 8),
#  ('Классическая музыка', 7),
#  ('Предприниматель', 7),
#  ('Онлайн-игра', 7),
#  ('Стример', 7),
#  ('Бар, паб', 7),
#  ('Музей, галерея, выставка', 7),
#  ('Школа', 7),
#  ('Цветы', 7),
#  ('Актёр / Актриса', 7),
#  ('Игра', 7),
#  ('Библиотека', 7),
#  ('Лёгкая атлетика', 6),
#  ('Парк развлечений', 6),
#  ('Психология', 6),
#  ('Киберспортивная организация', 6),
#  ('Другие услуги', 6),
#  ('Религиозное учреждение', 6),
#  ('Хоккей', 6),
#  ('Спорт и красота', 6),
#  ('Супермаркет', 6),
#  ('Танцы', 6),
#  ('Высокие технологии', 5),
#  ('Телекоммуникации', 5),
#  ('Концерт', 5),
#  ('Спортивные товары', 5),
#  ('Информационный портал', 5),
#  ('Консалтинг, бизнес-услуги', 5),
#  ('Печать, полиграфия', 5),
#  ('Организация праздников', 5),
#  ('Колледж', 5),
#  ('Некоммерческая организация', 5),
#  ('Туризм и отдых', 5),
#  ('Кинематограф', 5),
#  ('Дизайн-студия', 5),
#  ('Товары для праздников', 4),
#  ('Политик, госслужащий', 4),
#  ('Фитнес-центр', 4),
#  ('Профессиональные услуги', 4),
#  ('Киберспорт', 4),
#  ('Подготовка к свадьбе', 4),
#  ('Мультфильм', 4),
#  ('Такси', 4),
#  ('Спортивный комплекс', 4),
#  ('Фестиваль', 4),
#  ('Настольные игры', 4),
#  ('Автосалон', 4),
#  ('Студия звукозаписи', 4),
#  ('Дизайнер', 4),
#  ('Производство контента', 4),
#  ('Ролевые игры', 4),
#  ('Шоу-бизнес', 3),
#  ('Финансовые рынки', 3),
#  ('Интерьер', 3),
#  ('Режиссёр, продюсер', 3),
#  ('Кофейня', 3),
#  ('Родственники', 3),
#  ('Кафе', 3),
#  ('Хоккейная команда', 3),
#  ('Спортивная одежда и обувь', 3),
#  ('Строительство', 3),
#  ('Инди', 3),
#  ('Товары для творчества', 3),
#  ('Спектакль', 3),
#  ('Храм', 3),
#  ('Интернет', 3),
#  ('Украшения, бижутерия ', 3),
#  ('Модельное агентство', 3),
#  ('Лотерея, розыгрыш', 3),
#  ('Техникум', 3),
#  ('Композитор', 3),
#  ('Страхование', 3),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Ленинский районный суд г. Грозного - Чеченская Республика) от 09.06.2016 № 2-1420/2016',
#   3),
#  ('Зоопарк', 3),
#  ('Группа сокурсников', 2),
#  ('Страховая компания', 2),
#  ('Салоны сотовой связи', 2),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 02.06.2016 № 2-7888/2016',
#   2),
#  ('Политическая партия', 2),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Промышленный районный суд г. Владикавказа - Республика Северная Осетия - Алания) от 16.01.2018 № 2-150/2018',
#   2),
#  ('Дизайнерская студия', 2),
#  ('Охота и рыбалка', 2),
#  ('Транспорт', 2),
#  ('Публицист', 2),
#  ('Поэт', 2),
#  ('Автошкола', 2),
#  ('Институт', 2),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения ФНС от 22.06.2016 № 2-6-27/     2016-06-21-30-АИ',
#   2),
#  ('Юридические услуги', 2),
#  ('Зимние виды спорта', 2),
#  ('Актёр', 2),
#  ('Концертный зал', 2),
#  ('Ремонтная мастерская', 2),
#  ('Водный спорт', 2),
#  ('Художник', 2),
#  ('Компания', 2),
#  ('Компьютерная техника', 2),
#  ('Певец', 2),
#  ('Водный транспорт', 2),
#  ('Интернет-провайдер', 2),
#  ('Промышленное производство', 2),
#  ('Стоматология', 2),
#  ('Лицей', 2),
#  ('Баскетбол', 2),
#  ('Азартные игры', 2),
#  ('Критик', 2),
#  ('Туры, экскурсии', 2),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Парабельский районный суд - Томская область) от 26.01.2017 № 2-17/2017',
#   2),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Магасский районный суд - Республика Ингушетия) от 01.06.2016 № 2-1798/2016',
#   2),
#  ('Данный материал заблокирован на территории Российской Федерации по требованию Роскомнадзора на основании решения Генеральной прокуратуры № 27-27-2014/Ид1358-14 от 25.04.2014',
#   2),
#  ('Цирк', 2),
#  ('Музыкальный лейбл', 2),
#  ('Диеты, здоровое питание', 2),
#  ('Авиакомпания', 2),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 26.05.2016 № 2-7483/2016',
#   2),
#  ('Транспортные услуги', 2),
#  ('Ведущий / Ведущая', 2),
#  ('Бутик', 2),
#  ('Тату-салон', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Ленинский районный суд г. Грозного - Чеченская Республика) от 31.03.2016 № 2-696/16',
#   1),
#  ('Тренинг, семинар', 1),
#  ('Атлет', 1),
#  ('Аренда автомобилей', 1),
#  ('Аэропорт, вокзал', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Центральный районный суд г. Читы - Забайкальский край) от 26.04.2017 № 2-1892-2017',
#   1),
#  ('Мотоциклы и другая мототехника', 1),
#  ('Туризм', 1),
#  ('Оператор мобильной связи', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Центральный районный суд г. Тольятти - Самарская область) от 07.06.2016 № 2-4577/2016',
#   1),
#  ('Беременность, роды', 1),
#  ('Гостиница', 1),
#  ('Игры, игрушки', 1),
#  ('Компьютерные услуги', 1),
#  ('Ломбард', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании требования Генеральной прокуратуры Российской Федерации от 18.08.2014 № 27-27-2014/Ид670-14',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения ФНС от 25.07.2016 № 2-6-27/ 2016-07-25-70-АИ',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Промышленный районный суд г. Владикавказа - Республика Северная Осетия - Алания) от 25.07.2016 № 2-1159/16',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации решением Роскомнадзора №01КМ-7376 от 02.03.2014',
#   1),
#  ('Джаз', 1),
#  ('Теннис', 1),
#  ('Памятник культуры', 1),
#  ('Рынок', 1),
#  ('Бассейн', 1),
#  ('Технология', 1),
#  ('Аптека, оптика', 1),
#  ('Инвестиции', 1),
#  ('Бытовая техника', 1),
#  ('Турагентство', 1),
#  ('Детский сад', 1),
#  ('Футболист', 1),
#  ('Мебель и интерьер', 1),
#  ('Товары для животных', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 06.05.2016 № 2-7089/2016',
#   1),
#  ('Пошив и ремонт одежды', 1),
#  ('Квест', 1),
#  ('Оборудование', 1),
#  ('Метал', 1),
#  ('Галерея', 1),
#  ('Телепрограмма', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 07.09.2016 № 2-10963/2016',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда/уполномоченного федерального органа исполнительной власти (Промышленный районный суд г. Владикавказа - Республика Северная Осетия - Алания) от 23.07.2018 № 2-942/18',
#   1),
#  ('Полиграфия', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда/уполномоченного федерального органа исполнительной власти (Заводский районный суд г. Кемерово - Кемеровская область) от 05.09.2018 № 2а-2818/2018',
#   1),
#  ('Пассажирские перевозки', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Самарский районный суд г. Самары - Самарская область) от 27.03.2017 № 2-770/2017',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Безенчукский районный суд - Самарская область) от 18.10.2016 № 2-1142/16',
#   1),
#  ('Народная музыка, фолк', 1),
#  ('Спортивное питание', 1),
#  ('Курьерская служба', 1),
#  ('Платёжная система', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 30.08.2016 № 2-10987/2016',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения ФНС от 27.06.2016 № 2-6-27 2016-06-24-93-АИ',
#   1),
#  ('Услуги для владельцев животных', 1),
#  ('Товары для дачи, огорода', 1),
#  ('Прокат', 1),
#  ('Группа выпускников', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Промышленный районный суд г. Владикавказа - Республика Северная Осетия - Алания) от 13.02.2018 № 2-202/18',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда/уполномоченного федерального органа исполнительной власти (Автозаводский районный суд г. Тольятти) от 13.04.2018 № 2-4213/2018',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 23.08.2016 № 2-10978/2016',
#   1),
#  ('Группа памяти', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда/уполномоченного федерального органа исполнительной власти (Ленинский районный суд г. Самары - Самарская область) от 26.12.2018 № 2а-4680/2018',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Горно-Алтайский городской суд - Республика Алтай) от 06.07.2017 № 2-1284/2017',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Автозаводский районный суд г. Тольятти - Самарская область) от 07.09.2016 № 2-10959/2016',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Промышленный районный суд г. Владикавказа - Республика Северная Осетия - Алания) от 13.12.2017 № 2-1735/17',
#   1),
#  ('Летний лагерь ', 1),
#  ('Антиквариат', 1),
#  ('Киберспортсмен', 1),
#  ('Тексты, аккорды', 1),
#  ('Безопасность', 1),
#  ('Политик', 1),
#  ('Ресторан', 1),
#  ('Больница', 1),
#  ('Медицинский центр', 1),
#  ('Режиссёр', 1),
#  ('Велосипеды', 1),
#  ('Гимназия', 1),
#  ('Архив', 1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании требования Генеральной прокуратуры Российской Федерации от 12.03.2015 № 27-31-2015/Ид831-15',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Горно-Алтайский городской суд - Республика Алтай) от 26.06.2017 № 2-1234/2017',
#   1),
#  ('Данный материал заблокирован на территории Российской Федерации на основании решения суда (Октябрьский городской суд - Самарская область) от 08.12.2016 № 2-678/2016',
#   1),
#  ('Клининг', 1),
#  ('Певица', 1),
#  ('Детская одежда и обувь', 1),
#  ('Психолог', 1),
#  ('Грузоперевозки', 1),
#  ('Общественное питание', 1),
#  ('Группа одноклассников', 1)]

# %%
# %matplotlib qt
