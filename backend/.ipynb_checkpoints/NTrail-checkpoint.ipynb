# %% [markdown]
# # Проект SocialSearch

# %% [markdown]
# ## Материалы проекта
# Про графы:
# - [Хорошая статья на хабре про кластеризацию графив](https://habr.com/ru/company/dca/blog/265077/)
# - [алгоритм louvain](https://louvain-igraph.readthedocs.io/en/latest/index.html)
# - [Awesome Community Detection Research Papers](https://github.com/benedekrozemberczki/awesome-community-detection)
#
#
# Про нахождение информации о человеке:
# - https://bsfo.ru/threads/probiv-cheloveka-v-vk.4110/
# - https://www.iphones.ru/iNotes/705983
# - https://cryptoworld.su/5-sposobov-probit-informaciyu-o-cheloveke-v-seti/
# - https://habr.com/en/company/echelon/blog/321754/ Отличная статья на хабре
#
#
# Лайфкаки по поиску информации:
# - https://vk.com/feed?obj=1&q=&section=mentions
# - [Каталог пользователей вк](https://vk.com/catalog.php)
# - https://vk.com/foaf.php?id=245089915 Посмотреть код страницы
# - http://сервисы.гувм.мвд.рф/info-service.htm?sid=2000 Провека действительности паспорта
#
# Конкуренты (похожие проекты):
# - https://bazaman.ru/ Нахождение человека по данным. Работает хреново
# - https://poiski-people.ru/instrukziya.html Плохо работает [То, что нашли обо мне](https://poiski-people.ru/rossiya/moskva/boris-novichkov-moskva-90185.html)
# - https://people.yandex.ru (Поиск людей по различной информации)
# - https://poisk-help.ru/ Работает плохо [Обо мне](https://poisk-help.ru/rossiya/moskva/boris-novichkov-moskva-2959.html)
# - http://spys.one/vk/ Банальное копирование вк. Только информация со страницы пользователя
# - https://vk.barkov.net/userinfo.aspx Требует доступ к странице. Базовая информация
# - https://200vk.com базовый анализ странцицы. Слежка за пользователем. Поиск скрытых друзей и прочее
#
# Получение ключа доступа пользователя для vk api
# https://oauth.vk.com/authorize?client_id=7091370&scope=photos,audio,video,docs,notes,pages,status,offers,questions,wall,groups,notifications,stats,ads,offline,docs,pages,stats,notifications,wall,friends&response_type=token

# %% [markdown]
# ## Задачи проекта:
# 1. Найти человека по минимальномо количеству известных о нем данных
# 2. Получить всю возможную инфомацию о человеке из открытых источников (социальные сети, гос. порталы, гугл, некоторые сайты)
# 3. Проанализировать (аналитичестки, с помощью ML)
# 4. Предоставить все в красивом человеко-читаемом виде конечному потребителю (пользователю данного ресурса)

# %% [markdown]
# ## Информация о человеке
# ### Базовые аспекты
# *Поля страницы вк: first_name, last_name, photo_200, sex, bdate, city, country, relatives, home_town, maiden_name, relation*
# - Имя
# - Вевичья фамилия
# - Фото
# - Пол
# - Возраст
# - Страна
# - Родной город
# - Родственники
#
#
# ### Основная деятельность (в настоящем / прошлом)
# *Поля страницы вк: career, education, occupation, schools, universities, military*
# - Школа (класс, год)
# - Вуз (факультет, курс, год)
# - Работа (направленность, год)
# - Бизнес (направления, сайт и пр)
#
# ### Сетевая жизнь / Контакты
# *Поля страницы вк: nickname, online, site, exports, contacts, verified, last_seen, connections, followers_count*
# - Сайт
# - Все социальные сети
# - Подписчики
# - Verify
# - Приватный аккаунт
#
# ### Интересы / Занятия
# *Поля страницы вк: books, activities, movies, music, tv, trending, games, interests, quotes*
# - Увлечения
# - Хобби
# - Музыка Фильмы Игры Книги
#
# ### Характеристика / Анализ
# *Поля страницы вк: status, counters, personal, about*
#
# *Информация на основе всех имеющихся данных*
# - Экстраверт / Интроверт (в процентах)
# - Популярность в сети (Подписчики, друзья и тд)
# - Сетевая доступность (в процентах). Количество личной информации в сети
# - Общественный статус (один из нескольких вариантов)
# - Процент одиночных друзей (не состоящих в сообществах испытуемого)
# - Придумать еще что-нибудь!

# %% [markdown]
# ## Социальные сообщества человека
# **Любые группы людей, к которым относится испытуемый:**
# - Социальные объединения среди друзей
# - Сообщества на основе общих групп
# - Виртуальное объединение на основе общего интереса (несвязные друзья программисты)
#
# ### Операции над сообществами
# - Поиск полного коллектива из небольшой его части
#
# ### Параметры каждого объединения
# - Список всех объединяющих коллектив факторы (место учебы, интересы, возраст, пол и пр)
# - Связность сообщества (исходя из графа)
# - Размер сообщества (количество участников)
# - Тут можно много чего еще придумать!

# %% [markdown]
# ## Идеи
# - Брать людей связанных отношениями (поле на странице пользователя). Таким образом находить семьи и прочее
# - Выводить источник параметра и смежные данные по двойному щелчку мышки на него. Напимер пользователь видит число девушек в сообществе, делает двойной клик на это значение и открывается окно просмотра подробной информации, все аккаунты этих девушек с аватарками и ссылками на них, также в этом мини окне просмотра есть кнопка анализировать, после нажатия на которую открыватеся новая вкладка с полным аналзом данного сообщества людей.
# - Искать знакомых по фотографиям. Если на фото есть упомянание человека или с помощью распознавания лица. Сохранять аватарки для улучшения технологии
#
# ## Данные
# *Все данные делятся на 4 типа*
# ### 1. Сырые данные. (full_data) Вся информация полученная с помощью соответствущего апи.
#     - Содержат все необходимое
#     - Очень много весят
#     - Существует на уровне каждого класса информационного объекта. (VKUser, VKCommunity, IGUser, IGCommunity и пр)
#
#
# ### 2. Обработанные данные. (processed_data) Получены из сырых.
#     - Мало весят (выжимка из сырых данных)
#     - Содержат личную информацию (ники людей в сообществе, телефоны, и прочие частные вещи)
#     - Отсутствует маловажная информация (редко встечающаяся, шумовая, строковая)
#
#
# ### 3. Самое важное. Общая информация (clean_data).
#     - Это выжимка из обработанных данных
#     - Убраны все частности, только общие числовие или категориальные параметры
#     - Предназначино для машинного обучения и алгоритмической приоретизации данных
#     - Полностью сохраняется в базе данных для дальнейшего анализа. Обучения машинки
#
#
# ### 4. Пользовательская информация (output_data).
#     - То, что выводится непосредственно потребителю на фронт.
#     - Зависит от уровня доступа, привилегий, подписки и прочего.
#     - Зависит от типа запроса (общий пробив, получение конкретики и др)
#     - Формируется из всех 3х предыдущий пунктов:
#         - Доступ к full_data только по целевому запросу пользователя
#         - Результат работы модельки МЛ и алгоритмической обработки clean_data
#         - Самое важное из processed_data на основе анализа clean_data
#         - Получение исходников любого параметра

# %% [markdown]
# ## Наблюдения
# - Если брать случайных людей, то примерно у 1 процента на странице указан интаграм
# - Если приближаться к лимитам вк по запросам 950+ из 1000 максимум то апи начинает работать не корректно

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from main import *
import logging
# %matplotlib inline

MemoryCache.clear_memory()
logger.setLevel(logging.DEBUG)

# %%
def find_all_friends(target_user, assumptions=None, iterations=100):
    if not assumptions:
        assumptions = VKCommunity()
        
    assumptions += VKCommunity([target_user])
        
    possible_frinds = assumptions.friends()
    possible_frinds = possible_frinds.only_valid()
    print('possible_frinds', possible_frinds.size)
    possible_frinds.friends()
    possible_frinds.short_data
    friends = []
    i = 0
    used = set()
    while i < possible_frinds.size:
        print('Iteration:', i, '  Possible friends:', possible_frinds.size)
        if i % 30 == 0:
            best = possible_frinds.select(100)
            best.friends()
            best.short_data
        user = possible_frinds.select(1)[0]
        used.add(user)
        possible_frinds.counter[user.id] = 0
        if user.valid:
            if target_user in user.friends():
                user.print()
                friends += [user]
                fr = user.friends()
                fr = VKCommunity([node for node in fr.nodes if node not in used])
                possible_frinds = possible_frinds + fr
        i += 1
        if i > iterations:
            break
                
    return VKCommunity(friends)

# %%
find_all_friends(VKUser('https://vk.com/b80bb7740288fda1f201890375a60c8f'),
                 assumptions=VKCommunity('suchenochka'), iterations=10000).print()
# Out:
# possible_frinds 0

# %%
comm = VKUser('boris2000n').friends().select(10)
comm.print()
comm.counter[146074673] = -231
print()
comm.print()
# Out:
# 274928641 Женя Филиппов          https://vk.com/id274928641
# 328521729 Евгения Бондаренко     https://vk.com/id328521729
# 191922691 Александр Цхай         https://vk.com/id191922691
# This object is not valid
# 91888646 Михаил Новичков         https://vk.com/id91888646
# 168682516 Булат Шелхонов         https://vk.com/id168682516
# 319093782 Всеволод Балагуров     https://vk.com/id319093782
# 107893278 Андрей Губин           https://vk.com/id107893278
# 146074673 Дмитрий Дерюгин        https://vk.com/id146074673
# 217970740 Анна Пономарчук        https://vk.com/id217970740
#
# 274928641 Женя Филиппов          https://vk.com/id274928641
# 328521729 Евгения Бондаренко     https://vk.com/id328521729
# 191922691 Александр Цхай         https://vk.com/id191922691
# This object is not valid
# 91888646 Михаил Новичков         https://vk.com/id91888646
# 168682516 Булат Шелхонов         https://vk.com/id168682516
# 319093782 Всеволод Балагуров     https://vk.com/id319093782
# ...

# %%
from collections import Counter
c = Counter(a=3, b=1)
dict(c)
# Out:
# {'a': 3, 'b': 1}

# %%
url = 'boris2000n'
user = VKUser(url)
user_key_words = user.get_key_words()
print('Keywords:')
print(user_key_words)
print()
inst_usernames = user.friends().process_data()['username_instagram']
print('Instagram friends usernames list length:')
print(len(inst_usernames))
print()
community = InstCommunity(inst_usernames).valid_users
community = community.select(1000, rand=False).friends(include_self=True)
# InstCommunity(Tools.best_names_matches(community.select().get_key_words(), user_key_words)).select(10).print()
community.print()
# Out:
# DEBUG    Find bad username: Нет
# DEBUG    Find bad username: +100000863335697
# DEBUG    Find bad username: +1048321675299776
# Keywords:
# ['Борис Новичков', 'Борис', 'Новичков', 'boris2000n']
#
# # timeit __init__ eps:0.00006 time:747.1639986
# Instagram friends usernames list length:
# 19
#
# # timeit __init__ eps:0.00002 time:747.1732523
# # timeit __init__ eps:0.00002 time:747.176101
# # timeit __init__ eps:0.00000 time:747.1764257
# # timeit __init__ eps:0.00002 time:747.178142
# # timeit __init__ eps:0.00002 time:747.1795337
# # timeit __init__ eps:0.00003 time:747.180956
# # timeit __init__ eps:0.00001 time:747.1810236
# # timeit __init__ eps:0.00003 time:747.182499
# jolex_009 Просто Лексус 15       https://instagram.com/jolex_009/
# retarddesu  13                   https://instagram.com/retarddesu/
# fivol5 Fivol 11                  https://instagram.com/fivol5/
# _onelittledemon_ Оля Темникова 11  https://instagram.com/_onelittledemon_/
# ...

# %%
MemoryCache.save_memory()

# %%
from instagram import WebAgent, WebAgentAccount
from instagram import Account, Media
from glbal import logger
accounts_data = [('agniiamuraviova212', '58nwNOT6iA'), 
                 ('dinafomichiova4713', 'hjSOZ5Sx3g'), 
                 ('lidiiadrozdova5662', 'hOQXuhdJxX'), 
                 ('darinabobrova8107', 'AnNInVZcgP'), 
                 ('varvarabolshakova8794', 'PyvFqtfh1g'), 
                 ('agniiazhdanova541', 'S4ApKhUBKh'), 
                 ('kiraovchinnikova680', '414LKKrHPa'), 
                 ('varvarakniazeva9295', 'sWXduOEjWz')]
accounts = []
# for username, password in accounts_data:
#     agent = WebAgentAccount(username)
#     agent.auth(password)
#     accounts.append(agent)
agent = WebAgentAccount('agniiamuraviova212')
agent.auth('58nwNOT6iA')
agent.get_media(Account('0sweetblood'))
Account('loganpaul').__dict__
# Out:
# {'id': '493525227',
#  'username': 'loganpaul',
#  'full_name': 'Logan Paul',
#  'profile_pic_url': 'https://instagram.fhel6-1.fna.fbcdn.net/vp/13693fc2f43b6c066688110b56e532fd/5E1D782B/t51.2885-19/s150x150/61833265_363511360967887_3520754021616844800_n.jpg?_nc_ht=instagram.fhel6-1.fna.fbcdn.net',
#  'profile_pic_url_hd': 'https://instagram.fhel6-1.fna.fbcdn.net/vp/265dfe256b8a548f6745d0e006f0895a/5E22EBDB/t51.2885-19/s320x320/61833265_363511360967887_3520754021616844800_n.jpg?_nc_ht=instagram.fhel6-1.fna.fbcdn.net',
#  'fb_page': None,
#  'biography': 'pugilist. beef chief. fluent in wingdings\nGet your fight tickets 🥊↙️',
#  'follows_count': 398,
#  'followers_count': 16437022,
#  'media_count': 907,
#  'is_private': False,
#  'is_verified': True,
#  'country_block': False,
#  'media': {B01R-UxpxJI,
#   B09IJr2p6jQ,
#   B0oPHVLHwZk,
#   B19YHXHnT6R,
#   B1US1vbHexd,
#   B1mPuzhpMq3,
#   B2H0bR3ptzO,
#   B2Kh2B0JKJ4,
#   B2Uh_SXpfaI,
#   B2Z1HQrp5tP,
#   B2pJMFBJp2J,
# ...

# %%
количество элементов в запросе, время между запросами,сколько продержалось до 429 ошибки
50 0.5 150 agniiamuraviova212
50 0.5 68  dinafomichiova4713
50 0.5 100 lidiiadrozdova5662
50 0.5 100 agniiamuraviova212 опять (1) через примерно 5 минут
50 0.5 18  dinafomichiova4713 опять через 4 минуты
50 0.5 66  darinabobrova8107
50 0.5 100 varvarabolshakova8794
50 2   100 agniiazhdanova541
50 2  102  kiraovchinnikova680
50 0  100  lidiiadrozdova5662 спустя 10 минут (очнулся через 9 минут)
50 0  100  lidiiadrozdova5662 он же
Последовательно запускаю 2 клиента
2x 50 0(не делаю sleep так и так запросы выполняются последовательно) 66 agniiamuraviova212 dinafomichiova4713 
Повторяю тоже самое. Через 9 минут проснулся от 429
2x 50 0 200
3x 50 0 100
3x 50 0 109 (каждый запрос в тройке выполняется одновременно, каждая тройка последовательно)
1x 20 6 376
1x 20 2 159
получить информацию о профиле безлимитное количество раз. пробовал паралельно запустить 1000 запросов. 
Работает без проблем
1x 100 0 64
1x 100 0 69
1x 100 0 67
1x 100 0 61
1x 100 0 66
200 0 47
200 0 48
200 0 47
50 0 107
50 0 108
100 0 74
100 0 72
100 0 30 (другой query_hash)
100 0 32 подождал 3 минуты
# Out:
#   File "<ipython-input-164-c1e288536baa>", line 1
#     количество элементов в запросе, время между запросами,сколько продержалось до 429 ошибки
#                        ^
# SyntaxError: invalid syntax

# %%
l = ['trendcdmx', 'lemonland3', 'eldarik_sharafiev', 'vikulia_voinu', 'vasea3261']

# %%
def f(agent, count=50):
    try:
        res = agent.get_followers(Account(random.choice(l)), limit=count, count=count)
    except:
        return False
    return True

# %%
# %%time
k = 0
while True:
    res = [
        ThreadResult(target=f, args=(accounts[i],))
        for i in range(1)
    ]
    res = [
        item.execute()
        for item in res
    ]
    if not all(res):
        break
    k += 1
    print(k)
    time.sleep(0.5)
# Out:
# CPU times: user 119 ms, sys: 1.85 ms, total: 120 ms
# Wall time: 680 ms

# %%
# agent = WebAgentAccount('agniiamuraviova212')
# agent.auth('58nwNOT6iA')
# agent.get_media(Account('putin_leader'))
# Account('putin_leader').full_name
qs = ['c76146de99bb02f6415203be841dd25a']

# %%
import random
import time
k = 0
while True:
    count=100
    k += 1
    res = accounts[1].get_followers(Account(random.choice(l)), limit=count, count=count, query_hash='f2405b236d85e8296cf30347c9f08c2a')
    print(len(res[0]), k)
#     break
#     time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Projects/ipython_files/SocialSearch/instagram/agents.py in get_followers(self, account, pointer, count, limit, delay, query_hash, settings)
#    1144             try:
# -> 1145                 data = response.json()["data"]["user"]["edge_followed_by"]
#    1146                 edges = data["edges"]
#
# KeyError: 'edge_followed_by'
#
# During handling of the above exception, another exception occurred:
#
# UnexpectedResponse                        Traceback (most recent call last)
# <ipython-input-31-d5294579dbe4> in <module>
#       5     count=100
#       6     k += 1
# ----> 7     res = accounts[1].get_followers(Account(random.choice(l)), limit=count, count=count, query_hash='f2405b236d85e8296cf30347c9f08c2a')
#       8     print(len(res[0]), k)
#       9 #     break
#
# ...

# %%
from instagram import WebAgent, Account, WebAgentAccount

with open('instagram_accounts_data.txt', 'r') as f:
    inst_accounts_raw_data = f.read()
    
good_agents = []
inst_accounts_data = []
for line in inst_accounts_raw_data.split('\n'):
    line = line.strip()
    elements = line.split(':')
    if len(elements) == 4:
        inst_accounts_data.append((elements[0], elements[1]))
    
for username, password in inst_accounts_data:
    try:
        ac = WebAgentAccount(username)
        ac.auth(password)
        good_agents.append((username, password))
        print('GOOD', username)
    except:
        print('BAD', username)
        
print('All accounts count:', len(inst_accounts_data))
print('Good accounts count:', len(good_agents))
print('Bad accounts count:', len(inst_accounts_data) - len(good_agents))
print(repr(good_agents))
# Out:
# GOOD agniiamuraviova212
# GOOD dinafomichiova4713
# GOOD lidiiadrozdova5662
# GOOD darinabobrova8107
# BAD karolinafiodorova7156
# GOOD varvarabolshakova8794
# GOOD agniiazhdanova541
# GOOD kiraovchinnikova680
# GOOD varvarakniazeva9295
# BAD agniiafedoseeva9784
# GOOD agniiakolesnikova5157
# BAD karolinaignatova5231
# BAD dinarogova4678
# BAD darinasidorova5511
# BAD darinasazonova2973
# GOOD aleksandrakniazeva7955
# GOOD tamarazueva1062
# BAD elvirazhukova7840
# BAD dinafedoseeva5862
# GOOD iaroslavaignatova8267
# BAD leilakovaliova6560
# GOOD lidiiarogova4743
# GOOD ameliiafedoseeva674
# BAD ameliiasergeeva946
# BAD darinabogdanova403
# BAD iaroslavabespalova1694
# GOOD reginapanfilova1678
# BAD sabinastepanova1794
# GOOD varvarakhokhlova3462
# GOOD agatasuvorova6583
# GOOD lidiiaershova6477
# GOOD varvaraaksionova5004
# GOOD kamillabelousova5951
# GOOD elizavetakudriavtseva6928
# GOOD tamarakulakova2946
# GOOD elizavetabobyliova5180
# GOOD reginalikhachiova8613
# ...

# %%
good = [('agniiamuraviova212', '58nwNOT6iA'), ('dinafomichiova4713', 'hjSOZ5Sx3g'), ('lidiiadrozdova5662', 'hOQXuhdJxX'), ('darinabobrova8107', 'AnNInVZcgP'), ('varvarabolshakova8794', 'PyvFqtfh1g'), ('agniiazhdanova541', 'S4ApKhUBKh'), ('kiraovchinnikova680', '414LKKrHPa'), ('varvarakniazeva9295', 'sWXduOEjWz'), ('agniiafedoseeva9784', 'yhNb3U7fYd'), ('agniiakolesnikova5157', 'rDfIoQSOIf'), ('aleksandrakniazeva7955', 'V3WYCG1fQ4'), ('tamarazueva1062', 'vZ5r7U8pBe'), ('iaroslavaignatova8267', 'KuxLCuSD0V'), ('leilakovaliova6560', 'zEhAFUjFGU'), ('lidiiarogova4743', 'L9RtTctnuG'), ('ameliiafedoseeva674', 'v7iCXPTxGp'), ('ameliiasergeeva946', 'z5XYZp9iSM'), ('reginapanfilova1678', 'xFzyYhKITD'), ('sabinastepanova1794', '1nlR5Tecpl'), ('varvarakhokhlova3462', 'Y01DVVGrJp'), ('agatasuvorova6583', '8DelwWXf5x'), ('lidiiaershova6477', '40FkUNxdVm'), ('varvaraaksionova5004', 'S6KLputgGG'), ('kamillabelousova5951', 'b0Giqt1aWI'), ('elizavetakudriavtseva6928', 'lg0GbPUxJv'), ('tamarakulakova2946', 'Wf8wjgwL3B'), ('elizavetabobyliova5180', 'JsbhlnEr4B'), ('reginalikhachiova8613', 'EFzPZSQppY'), ('leilakalinina4900', 'nWh8KCQjjD'), ('iaroslavabelousova121', 'LUn8gN8M6b'), ('reginakovaliova726', 'mstGZkoHt0'), ('iaroslavaalekseeva5882', 'pRbrgZH47R'), ('leilagordeeva2201', 'ZOPjfCua2w'), ('agatanikitina2554', 'zmiN0MXdMx'), ('ameliiasharapova9216', 'vGnWISq6PE')]
len(good) / 50
# Out:
# 0.7

# %%
# %matplotlib inline
user = VKUser('https://vk.com/didiv2000')
#user.friends_com.color_communities(user.friends_com.split())
plt.hist(user.friends_com.params['age_list'], bins=25)
plt.show()
user.friends_com.params['age_median']
# Out:
# 40.12472437003373

# %%
print(len(activities_types))
activities_types.most_common()
# Out:
# 370
# [('Юмор', 860),
#  ('Кино', 608),
#  ('Городское сообщество', 563),
#  ('Интернет-СМИ', 448),
#  ('Обмен музыкой', 416),
#  ('Творчество', 368),
#  ('Публичная страница', 348),
#  ('Кулинария, рецепты', 342),
#  ('Литература', 304),
#  ('Отношения полов', 276),
#  ('Уход за собой', 255),
#  ('Образование', 255),
#  ('Наука', 251),
#  ('ВКонтакте', 244),
#  ('Объявления', 244),
#  ('Общество', 235),
#  ('Молодёжное движение', 224),
#  ('Шоу, передача', 211),
#  ('Бизнес', 209),
#  ('Знакомства', 200),
#  ('Здоровый образ жизни', 193),
#  ('Философия', 190),
#  ('Стиль, одежда, обувь', 186),
#  ('Фотография', 166),
#  ('Туризм, путешествия', 162),
#  ('Автомобили', 148),
#  ('Дизайн интерьера', 147),
#  ('Музыка', 143),
#  ('Игры', 134),
#  ('Телеканал', 129),
#  ('Родители и дети', 126),
#  ('Фитнес', 125),
#  ('Культура', 102),
#  ('Друзья', 99),
#  ('СМИ', 95),
#  ('Строительство, ремонт', 89),
#  ('Поиск работы', 88),
#  ('Вымышленный персонаж', 86),
#  ('Сайты', 85),
# ...

# %% [markdown]
# ## Нахождение полного сообщества по нескольким участникам

# %%
def print_func_plot(func, params, x=None):
    results = []
    for args in params:
        results.append(func(**args))
    if x is None:
        x = range(len(results))
    plt.plot(x, results)
    plt.show()

# %%
x = np.linspace(0.1, 0.98, num=20)
print_func_plot(
    get_community_size, 
    [
        {
            'weight_reduction_ratio': i,
            'break_point': 10,
        }
        for i in x
    ],
    x=x
)

# %% [markdown]
# ## Нахождение общего знаменателя среди сообщества (школа, вуз, место жительста, группы вк и т.д)

# %%
from tqdm import tqdm_notebook as tqdm
for i in tqdm(range(2)):
    size = np.random.randint(20, 250)
    params = Community.generate_random(size).get_special_params()
#     print(params)
    CommunityData.create(data=params)

# %%
comm_data = [i.data for i in CommunityData.select().execute()]
def param_list(key):
    return [x[key] for x in comm_data]
params = ['community_size', 'sex_mean', 'age_median', 'city_first_fr', 
'country_first_fr', 'online_mean', 'online_mobile_mean', 
'verified_mean', 'last_seen_mean', 'last_seen_amax', 
'last_seen_median', 'site_fr', 'followers_count_mean', 
'followers_count_median', 'followers_count_amax', 'home_town_first_fr', 
'occupation_type_first_fr', 'occupation_name_first_fr', 'personal_langs_first_fr', 
'personal_political_first_fr', 'personal_religion_first_fr', 'personal_people_main_first_fr', 
'personal_smoking_first_fr', 'personal_alcohol_first_fr', 'personal_life_main_first_fr', 
'relatives_childs_fr', 'relation_first_fr', 'schools_first_fr', 
'schools_type_str_first_fr', 'status_fr']

# %%
# Community.generate_random(1).special_params
for p in params:
    print(p)
    l = param_list(p)
    plt.hist(l, 20)
    plt.show()
# Out:
# community_size
# sex_mean
# age_median
# city_first_fr
# country_first_fr
# online_mean
# online_mobile_mean
# verified_mean
# last_seen_mean
# last_seen_amax
# last_seen_median
# site_fr
# followers_count_mean
# followers_count_median
# followers_count_amax
# home_town_first_fr
# occupation_type_first_fr
# occupation_name_first_fr
# personal_langs_first_fr
# personal_political_first_fr
# personal_religion_first_fr
# personal_people_main_first_fr
# personal_smoking_first_fr
# personal_alcohol_first_fr
# personal_life_main_first_fr
# relatives_childs_fr
# relation_first_fr
# schools_first_fr
# schools_type_str_first_fr
# status_fr

# %%
key_importance = []
target_community = comm1.get_params()

for key in params:
    target_element = target_community[key]
#     print(target_element)
    hist_list = param_list(key)
    bins = 10
    hist_values, hist_x = np.histogram(hist_list, bins)
#     plt.hist(hist_list, bins)
#     plt.show()
#     print(hist_x)
    if target_element < hist_x[0]:
        hist_value = 0
    elif target_element > hist_x[-1]:
        hist_value = 0
    else:
        hist_column = np.where(hist_x <= target_element)[0][-1]
        hist_value = hist_values[hist_column]

    hist_max = np.max(hist_values)
    element_importance = hist_value / hist_max
    key_importance.append((element_importance, key))
#     print(hist_max)
#     print(element_fr)
[print(i) for i in sorted(key_importance)]
None
# Out:
# * Get user data 229170215
# * Get user data 2384937
# * Get user data 327191868
# * Get user data 1727556
# * Get user data 150879566
# * Get user data 349087825
# * Get user data 305752720
# * Get user data 280349348
# * Get user data 332072868
# * Get user data 179897523
# * Get user data 203419100
# (0.0, 'age_median')
# (0.0, 'city_first_fr')
# (0.0, 'country_first_fr')
# (0.0, 'followers_count_median')
# (0.0, 'home_town_first_fr')
# (0.0, 'last_seen_amax')
# (0.0, 'last_seen_mean')
# (0.0, 'last_seen_median')
# (0.0, 'occupation_name_first_fr')
# (0.0, 'occupation_type_first_fr')
# (0.0, 'online_mean')
# (0.0, 'schools_first_fr')
# (0.0, 'schools_type_str_first_fr')
# (0.0, 'status_fr')
# (0.012, 'online_mobile_mean')
# (0.07692307692307693, 'site_fr')
# (0.09818181818181818, 'followers_count_mean')
# (0.13664596273291926, 'personal_smoking_first_fr')
# (0.20382165605095542, 'personal_alcohol_first_fr')
# (0.21674876847290642, 'personal_people_main_first_fr')
# ...

# %%
from instagram.client import InstagramAPI

client_id  = 'c6ab41f3c1094082aadf0cc0c6c4bb27'
client_secret = '16a8afe3350a43d697ac5138881c94fc'
access_token = '12638820603.c6ab41f.cad5b7d0690b496691583fc689a03b10'

api = InstagramAPI(client_id=client_id, client_secret=client_secret, access_token=access_token)

follows, next_ = api.user_follows()
# Out:
# ---------------------------------------------------------------------------
# InstagramAPIError                         Traceback (most recent call last)
# <ipython-input-15-6155a1430d9a> in <module>
#       7 api = InstagramAPI(client_id=client_id, client_secret=client_secret, access_token=access_token)
#       8
# ----> 9 follows, next_ = api.user_follows()
#
# ~/anaconda3/lib/python3.7/site-packages/instagram/bind.py in _call(api, *args, **kwargs)
#     195     def _call(api, *args, **kwargs):
#     196         method = InstagramAPIMethod(api, *args, **kwargs)
# --> 197         return method.execute()
#     198
#     199     return _call
#
# ~/anaconda3/lib/python3.7/site-packages/instagram/bind.py in execute(self)
#     187                 return self._paginator_with_url(url, method, body, headers)
#     188             else:
# --> 189                 content, next = self._do_api_request(url, method, body, headers)
#     190             if self.paginates:
# ...

# %%
from instagram.client import InstagramAPI
import sys

if len(sys.argv) > 1 and sys.argv[1] == 'local':
    try:
        from test_settings import *

        InstagramAPI.host = test_host
        InstagramAPI.base_path = test_base_path
        InstagramAPI.access_token_field = "access_token"
        InstagramAPI.authorize_url = test_authorize_url
        InstagramAPI.access_token_url = test_access_token_url
        InstagramAPI.protocol = test_protocol
    except Exception:
        pass

# Fix Python 2.x.
try:
    import __builtin__
    input = getattr(__builtin__, 'raw_input')
except (ImportError, AttributeError):
    pass

client_id = input("Client ID: ").strip()
client_secret = input("Client Secret: ").strip()
redirect_uri = input("Redirect URI: ").strip()
raw_scope = input("Requested scope (separated by spaces, blank for just basic read): ").strip()
scope = raw_scope.split(' ')
# For basic, API seems to need to be set explicitly
if not scope or scope == [""]:
    scope = ["basic"]

api = InstagramAPI(client_id=client_id, client_secret=client_secret, redirect_uri=redirect_uri)
redirect_uri = api.get_authorize_login_url(scope = scope)

print ("Visit this page and authorize access in your browser: "+ redirect_uri)

code = (str(input("Paste in code in query string after redirect: ").strip()))

access_token = api.exchange_code_for_access_token(code)
print ("access token: " )
print (access_token)
# Out:
# Client ID: c6ab41f3c1094082aadf0cc0c6c4bb27
# Client Secret: 16a8afe3350a43d697ac5138881c94fc
# Redirect URI: https://rudrastyh.com/tools/access-token
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# ...

# %%
from instagram import Account, Media, WebAgent

agent = WebAgent()
account = Account("fivol5")

# media_objects, pointer = agent.get_media(account)
media, pointer = agent.get_media(account, count=20, delay=1)

# %%
# obj = media1[3]
# for item in dir(obj):
#     print(item, getattr(obj, item))

# %%
keys = ['caption', 'date', 'display_url', 'likes_count', 'comments_count']
for obj in media_objects:
    print(obj.display_url)
# Out:
# https://scontent-amt2-1.cdninstagram.com/vp/1b57e342eaf4c8802078f1ab01c541aa/5E24A260/t51.2885-15/e35/71024929_232709697697918_8404479157268540884_n.jpg?_nc_ht=scontent-amt2-1.cdninstagram.com&_nc_cat=110
# https://scontent-amt2-1.cdninstagram.com/vp/bd544b9ced95cc3ca29ed2f98f0ceb89/5E1758BD/t51.2885-15/e35/69357277_107572600505017_2119080385914866789_n.jpg?_nc_ht=scontent-amt2-1.cdninstagram.com&_nc_cat=101
# https://scontent-amt2-1.cdninstagram.com/vp/85672d75945507b84be01460634949f7/5E04AC80/t51.2885-15/e35/69805450_133553997927918_5874482647860257742_n.jpg?_nc_ht=scontent-amt2-1.cdninstagram.com&_nc_cat=106
# https://scontent-amt2-1.cdninstagram.com/vp/4d579b5be46908036d95f0c98ee63310/5E3675F1/t51.2885-15/e35/69143631_493140504832604_7395125488741647540_n.jpg?_nc_ht=scontent-amt2-1.cdninstagram.com&_nc_cat=108
# ...

# %%
from instagram import WebAgentAccount
from instagram import Account, Media, WebAgent

# agent = WebAgentAccount("fivol5")
# agent.auth('dlz08UtKFinst')

agent2 = WebAgentAccount('borfiner')
agent2.auth('dlz08UtKFfivol')
# f = agent2.get_follows(Account('cuvoe'), delay=0)[0]
# f = agent.get_follows(Account('cuvoe'), delay=0, count=100)[0]
agent2.username
# Out:
# 'borfiner'

# %%
data, pointer = agent.get_follows(Account('cuvoe'), delay=0)
data2 = agent2.get_follows(pointer=pointer, delay=0)[0]
# print(data)
print(data, data2)
# Out:
# [taetaebooo, jypetwicenayeon, killrtaekook, _s.kripton_, svyatalina, essie_amy334, msuga1628, diakka__, astmodeus, yukokiro, mikialiet, the.kurb, my_afterglow_, jisoo.mp4, larkicheva, ester_exposito, jung_mariia, ugllliver.r, orthvs, jhopetv] [on_seish, al.boss006, mishalaz, kirillovphoto, vladomot]

# %%
for i in f:
    print(i)
    d = agent2.get_follows(Account(i), count=100, delay=0)[0]
    print(d)
# Out:
# taetaebooo
# [malive.art, fabxiao, vanillahobie, bts.biighitofical, hannes_becker, koosarchive, shooky_dough, reiz_i, chungha_official, bts.world.official, koalaguk, iamhalsey, randomsplashes, kookiechimm, 2ah.in, hyundai.lifestyle, for__infinity, jiminskth, boo.archive, miyayeah, bn_sj2013, selenaspiral, ireneisgood, dora._.a, debaek, kimtaehyungscloset, winter_strawverry, _nuna_v, bt21club, mejiwoo103, bts_love_myself, bt21_official, sonsungdeuk, bighit_exhibition, bts.bighitofficial]
# jypetwicenayeon
# ...

# %%
html_users_data = '''<div class="module_body module_body2"><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-14.userapi.com/c855128/v855128933/107af6/88QAxQjyyqg.jpg?ava=1)"><a href="https://vk.com/rock_3bc" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/rock_3bc" target="_blank" class="people_cell_name">Слава <span>Самсонов</span></a><a href="https://vk.com/rock_3bc" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-19.userapi.com/c849128/v849128701/896a2/V5Ya8_crCR0.jpg?ava=1)"><a href="https://vk.com/tupo_fopf" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/tupo_fopf" target="_blank" class="people_cell_name">Демид <span>Дорогинин</span></a><a href="https://vk.com/tupo_fopf" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-3.userapi.com/nSPypyUXFvxiKdHbFl-Kb98qK-9sDAKLBmD7Zw/xXfSf2DuQY4.jpg?ava=1)"><a href="https://vk.com/popelyshev" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/popelyshev" target="_blank" class="people_cell_name">Иван <span>Попелышев</span></a><a href="https://vk.com/popelyshev" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-57.userapi.com/c849324/v849324313/e1dd/_1UDzGsUYFQ.jpg?ava=1)"><a href="https://vk.com/id226173103" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/id226173103" target="_blank" class="people_cell_name">Василиса <span>Огнева</span></a><a href="https://vk.com/id226173103" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-63.userapi.com/c837620/v837620272/34c01/DxPYfDqm0yI.jpg?ava=1)"><a href="https://vk.com/id300320272" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/id300320272" target="_blank" class="people_cell_name">Слава <span>Юшков</span></a><a href="https://vk.com/id300320272" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-66.userapi.com/c858020/v858020517/82c42/hUx0_EP-1_o.jpg?ava=1)"><a href="https://vk.com/id200128077" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/id200128077" target="_blank" class="people_cell_name">Паша <span>Козырь</span></a><a href="https://vk.com/id200128077" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun1-15.userapi.com/c858216/v858216178/99e71/NMeN2qkNQsI.jpg?ava=1)"><a href="https://vk.com/naduhaswim" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/naduhaswim" target="_blank" class="people_cell_name">Надежда <span>Захарова</span></a><a href="https://vk.com/naduhaswim" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9
target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun1-22.userapi.com/c854216/v854216009/dff83/e7C-XI-viOY.jpg?ava=1)"><div class="people_cell_img_online_min online online_min mobile"></div><div class="people_cell_img_online_max online online_max mobile"></div><a href="https://vk.com/scushna" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/scushna" target="_blank" class="people_cell_name">Максим <span>Копец</span></a><a href="https://vk.com/scushna" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-49.userapi.com/c856032/v856032899/30609/V7yYz0AYiF0.jpg?ava=1)"><div class="people_cell_img_online_min online online_min mobile"></div><div class="people_cell_img_online_max online online_max mobile"></div><a href="https://vk.com/ivaanq" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/ivaanq" target="_blank" class="people_cell_name">Иван <span>Потяшин</span></a><a href="https://vk.com/ivaanq" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun1-14.userapi.com/c627520/v627520763/499d9/tdTLTiUj1a0.jpg?ava=1)"><a href="https://vk.com/erlikhivan" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/erlikhivan" target="_blank" class="people_cell_name">Иван <span>Эрлих</span></a><a href="https://vk.com/erlikhivan" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun1-21.userapi.com/c847219/v847219059/23f6a/kyjZxV9Jil8.jpg?ava=1)"><a href="https://vk.com/heartr8" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/heartr8" target="_blank" class="people_cell_name">Денис <span>Осокин</span></a><a href="https://vk.com/heartr8" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun1-90.userapi.com/c849232/v849232126/78549/Y53tenUgI4g.jpg?ava=1)"><a href="https://vk.com/raufmaharam" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/raufmaharam" target="_blank" class="people_cell_name">Рауф <span>Мухарамов</span></a><a href="https://vk.com/raufmaharam" target="_blank" class="a_absolute"></a></div><div class="people_cell"><div class="people_cell_img" style="background-image:url(https://sun9-62.userapi.com/c857728/v857728845/267b5/I7n-8DQhpWw.jpg?ava=1)"><a href="https://vk.com/katya11111" target="_blank" class="a_absolute"></a></div><a href="https://vk.com/katya11111" target="_blank" class="people_cell_name">Катерина <span>Крупник</span></a><a href="https://vk.com/katya11111" target="_blank" class="a_absolute"></a></div></div>'''

# %%
import re
exp = r'https://vk.com/([^"]+)'
usernames = list(set(re.findall(exp, html_users_data)))
print(usernames)
# Out:
# ['lemmemlem', 'vlar_rus', 'egorzverev1', 'id302193902', 'smiltcmm', 'soshikan', 'id111141867', 'paveg17', 'k_sofi', 'melisey', 'andtit2001', 'raufmaharam', 'idaut', 'sashalab', 'nastysh2001', 'id__4', 'id107757043', 'id160438550', 'marie_fofanova', 'ksuab', 'leleytner', 'dandy_forever', 'id85835366', 'heartr8', 'lexolordan', 'id_itswheremydemonshide', 'kulart00', 'sergo_the_roach', 'elevely', 'tiebetie', 'purfreak', 'ksolzh', 'id97015690', 'citsampla', 'a2112', 'sinoosoida', 'sir_polin', 'krasnow.witas', 'vse_1000000007', 'artek_chumak', 'id50166259', 'rationalex', 'id62695621', 'id3552831', 'tbfox', 'begi_9898', 'yuliya_kvardakova', 'thrash_yura', 'efimovdan', 'id274610451', 'ocupofteao', '1oolove', 'kwalex', 'shamash42', 'patlin', 'id143161205', 'nikomorfine', 'daniilserebrennikov', 'id155184715', 'argentum049', 'id8351502', 'yaskew', 'vladderq', 'aslepnyov0', 'animov_sasat', 'rock_3bc', 'm.kruglov1999', 'tupo_fopf', 'milltanya', 'cromtus', 'kermit_froggy19', 'mymidi', 'id52593464'
# ...
